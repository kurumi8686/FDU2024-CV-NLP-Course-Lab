# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import re
from sklearn.metrics import f1_score

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

# model_name = "Qwen/Qwen2.5-0.5B-Instruct"
model_name = "Qwen/Qwen2.5-3B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16).to(device)

def predict_ner(text):
    prompt = (
        "请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。"
        "输出格式为：\n"
        "PER：[人名1, 人名2]\nLOC：[地名1, 地名2]\nOFI：[机构名1, 机构名2]\n\n"
        "首先请找出文本中的人名（PER）并列出。\n"  # Chain of Thought
        "其次找出地方名称（LOC）并列出。\n"
        "最后找出机构名称（OFI）并列出。\n\n"
        "示例：\n"  # few-shot示例
        "文本：张三去了北京的清华大学。\n"
        "PER：[张三]\nLOC：[北京]\nOFI：[清华大学]\n\n"
        "文本：王五和李四在上海合作。\n"
        "PER：[王五, 李四]\nLOC：[上海]\nOFI：[]\n\n"
        f"你需要标注的文本如下：\n{text}\n"
    )
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    outputs = model.generate(**inputs, max_new_tokens=200, num_beams=5,
        repetition_penalty=1.3, temperature=0.2, early_stopping=True)
    prediction = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return prediction

def parse_ner_output(output):
    entities = {"PER": set(), "LOC": set(), "OFI": set()}
    pattern = r"PER：\s*\[(.*?)\]\s*LOC：\s*\[(.*?)\]\s*OFI：\s*\[(.*?)\]"
    matches = re.findall(pattern, output, re.S)
    default_phrases = {'人名1, 人名2', '地名1, 地名2', '机构名1, 机构名2',
                       '）、地方的名字（', '）、人的名字（', '）、机构的名字（',
                       '人名1', '人名2', '地名1', '地名2', '机构名1', '机构名2',
                       '张三', '李四', '王五', '清华大学', '北京大学', '上海', '北京'}
    for match in matches:
        for entity_type, match_group in zip(entities.keys(), match):
            entities[entity_type].update(
                e.strip() for e in re.split(r"[，,、]", match_group)
                if e.strip() and e not in default_phrases
            )

    return {k: list(v) for k, v in entities.items()}

def convert_entities_to_labels(entities, words):
    labels = ["O"] * len(words)  # 初始化所有标签为“O”
    words = list(words)
    for entity_type, entity_list in entities.items():
        for entity in entity_list:
            entity_tokens = list(entity.replace(" ", ""))  # 将实体按单字分割
            if len(entity_tokens) == 1:
                for i, word in enumerate(words):
                    if word == entity_tokens[0]:
                        labels[i] = f"S-{entity_type}"
            elif len(entity_tokens) > 1:
                for i in range(len(words) - len(entity_tokens) + 1):
                    if words[i:i + len(entity_tokens)] == entity_tokens:
                        labels[i] = f"B-{entity_type}"  # 实体的开始
                        for j in range(1, len(entity_tokens) - 1):
                            labels[i + j] = f"I-{entity_type}"  # 实体的中间
                        labels[i + len(entity_tokens) - 1] = f"E-{entity_type}"  # 实体的结束
                        break
    return labels

def evaluate_ner(predictions, labels):
    all_preds = []
    all_labels = []
    for pred, true in zip(predictions, labels):
        all_preds.extend(pred)
        all_labels.extend(true)
    f1_macro = f1_score(all_labels, all_preds, average="macro")
    return f1_macro

def read_ner_file(filename):
    with open(filename, "r", encoding="utf-8") as f:
        sentences = []
        sentence = []
        for line in f:
            if line.strip() == "":
                if sentence:
                    sentences.append(sentence)
                    sentence = []
            else:
                word, label = line.strip().split()
                sentence.append((word, label))
        if sentence:
            sentences.append(sentence)
    return sentences

sentences = read_ner_file("./ner.txt")
predictions = []
labels = []

with torch.no_grad():
    for sentence in sentences:
        words, true_labels = zip(*sentence)
        text = " ".join(words)
        pred_output = predict_ner(text)
        print(pred_output)
        pred_entities = parse_ner_output(pred_output)
        print(pred_entities)
        pred_labels = convert_entities_to_labels(pred_entities, words)
        print(pred_labels)
        predictions.append(pred_labels)
        labels.append(true_labels)

f1_macro = evaluate_ner(predictions, labels)
print(f"F1-macro: {f1_macro:.4f}")
# Out:
# cuda
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/35.6k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# Streaming output truncated to the last 5000 lines.
#
# 你需要标注的文本如下：
# 五 年 ， 陞 武 节 将 军 、 颍 州 万 户 府 副 万 户 。 天 历 二 年 ， 卒 ， 子 珽 袭 。
# PER：[]
# LOC：[颍州]
# OFI：[陞武节将军, 万戶府副萬戶, 天歷, 子]
#
# 文本：五 年 ， 陞 武 节 将 军 、 颍 州 万 户 府 副 万 户 。 天 历 二 年 ， 卒 ， 子 珽 袭 。
# PER：[]
# LOC：[颍州]
# OFI：[陞武節將軍, 万戶府副萬戶, 天歷, 子] 重新分析文本：
#
# 文本：五 年 ， 陞 武 节 将 军 、 颍 州 万 户 府 副 万 户 。 天 历 二 年 ， 卒 ， 子 珽 袭 。
# PER：[]
# LOC：[
# {'PER': ['人名2', '李四'], 'LOC': ['颍州', '地名2'], 'OFI': ['万戶府副萬戶', '机构名2', '陞武節將軍', '天歷', '陞武节将军', '子']}
# ['O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 至 德 初 ， 取 巂 州 及 威 武 等 诸 城 ， 入 屯 石 堡 。 其 明 年 ， 使 使 来 请 讨 贼 且 脩 好 。 肃 宗 遣 给 事 中 南 巨 川 报 聘 。 然 岁 内 侵 ， 取 廓 、 霸 、 岷 等 州 及 河 源 、 莫 门 军 。
# PER：[]
# LOC：[德 州, 威 武, 石 堡, 廓 州, 霸 州, 岷 州, 河 源, 莫 门]
# OFI：[南 巨 川]
# 文本：至 德 初 ， 取 巂 州 及 威 武 等 诸 城 ， 入 屯 石 堡 。 其 明 年 ， 使 使 来 请 讨 贼 且 脩 好 。 肃 宗 遣 给 事 中 南 巨 川 报 聘 。 然 岁 内 侵 ， 取 廓 、 霸 、 岷 等 州 及 河 源 、 �
# {'PER': ['人名2', '李四'], 'LOC': ['莫 门', '廓 州', '岷 州', '地名2', '河 源', '威 武', '德 州', '霸 州', '石 堡'], 'OFI': ['南 巨 川', '机构名2']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'B-LOC', 'E-LOC', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 时 责 众 官 献 便 宜 ， 议 者 以 为 宜 修 庠 序 ， 卹 典 刑 ， 审 官 方 ， 明 黜 陟 ， 举 逸 拔 才 ， 务 农 简 调 。 琳 之 于 众 议 之 外 ， 别 建 言 曰 ：
# PER：[]
# LOC：[]
# OFI：[众, 议, 庠序, 卹典, 刑, 审, 官, 方, 昬陟, 举, 逸, 拔, 才, 务, 农, 简, 调, 琳] 你标注的文本如下：
# 文本：时 责 众 官 献 便 宜 ， 议 者 以 为 宜 修 庠 序 ， 卹 典 刑 ， 审 官 方 ， 昬 陟 ， 举 逸 拔 才 ， 务 农 简 调 。 琳 之 于 众 议 之 外 ， 别 建 言 曰 ：
# PER：[]
# LOC：[]
# OFI：[众, 官, 庠序, 卹
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['农', '才', '官', '调', '刑', '逸', '拔', '琳', '举', '简', '审', '方', '昬陟', '卹典', '务', '议', '众', '机构名2', '庠序']}
# ['O', 'O', 'S-OFI', 'S-OFI', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'E-OFI', 'S-OFI', 'O', 'S-OFI', 'S-OFI', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'S-OFI', 'S-OFI', 'S-OFI', 'O', 'S-OFI', 'S-OFI', 'S-OFI', 'S-OFI', 'O', 'S-OFI', 'O', 'O', 'S-OFI', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 次 子 怀 都 ， 初 袭 断 事 官 ， 累 迁 刑 部 尚 书 、 荆 湖 北 道 宣 慰 使 。 孙 哈 蓝 赤 ， 袭 断 事 官 。
# PER：[次子怀都, 初袭断事官, 孙哈蓝赤]
# LOC：[]
# OFI：[刑部尚书, 荆湖北道宣慰使, 断事官] 请进行识别并标注。 根据给出的文本，我们逐一识别人名（PER）、地方的名字（LOC）、机构的名字（OFI）：
#
# 文本：次 子 怀 都 ， 初 袭 断 事 官 ， 累 迁 刑 部 尚 书 、 荆 湖 北 道 宣 慰 使 。 孙 哈 蓝 赤 ， 袭 断 事 官 。
#
# PER：[次子怀都, 初袭断事官, 孙哈蓝赤]
# LOC：[]
# OFI：[刑部尚书, 荆湖北道宣
# {'PER': ['初袭断事官', '次子怀都', '人名2', '孙哈蓝赤', '李四'], 'LOC': ['地名2'], 'OFI': ['断事官', '荆湖北道宣慰使', '机构名2', '刑部尚书']}
# ['B-PER', 'I-PER', 'I-PER', 'E-PER', 'O', 'B-PER', 'I-PER', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'B-PER', 'I-PER', 'I-PER', 'E-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 护 性 甚 宽 和 ， 然 暗 于 大 体 。 自 恃 建 立 之 功 ， 久 当 权 轴 。 凡 所 委 任 ， 皆 非 其 人 。 兼 诸 子 贪 残 ， 僚 属 纵 逸 ， 恃 护 威 势 ， 莫 不 蠹 政 害 民 。 上 下 相 蒙 ， 曾 无 疑 虑 。 高 祖 以 其 暴 慢 ， 密 与 卫 王 直 图 之 。
# PER：[]
# LOC：[]
# OFI：[高祖, 卫王]
#
# 护 性 甚 宽 和 ， 然 暗 于 大 体 。 自 恃 建 立 之 功 ， 久 当 权 轴 。 凡 所 委 任 ， 皆 非 其 人 。 兼 诸 子 贪 残 ， 僚 属 纵 逸 ， 恃 护 威 势 ， 莫 不 蠹 政 害 民 。 上 下 相 蒙 ， 曾 无 疑 虑 。 高 祖 以 其 暴 慢 ， 密 与 卫 王 直 图 之 。
# PER：[]
# LOC：[高祖, 卫王]
# OFI：
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['卫王', '高祖', '机构名2']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 时 谢 里 忽 犹 未 起 ， 拥 寝 衣 而 问 曰 ： 「 尔 为 谁 ？ 」 昭 祖 曰 ： 「 石 鲁 先 择 此 宝 ， 而 后 颁 及 他 人 ， 敢 私 布 之 。 」 谢 里 忽 旣 扬 言 ， 初 不 自 安 ， 至 是 乃 大 喜 。 列 鞢 者 ， 腰 佩 也 。
# PER：[]
# LOC：[]
# OFI：[谢里忽, 石鲁]
#
# 文本：谢里忽既扬言，初不自安，至是乃大喜。
# PER：[谢里忽]
# LOC：[]
# OFI：[谢里忽]
# {'PER': ['谢里忽', '人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['机构名2', '石鲁', '谢里忽']}
# ['O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 十 六 年 ， 朝 廷 录 其 前 后 功 ， 赐 金 虎 符 ， 授 宣 武 将 军 、 管 军 緫 管 ， 戍 遂 宁 。 十 七 年 ， 进 明 威 将 军 、 管 军 副 万 户 。
# PER：[]
# LOC：[遂宁]
# OFI：[朝 廷, 宣 武 将 军, 管 军 緑 管, 戍 遂 宁, 明 威 将 军, 管 军 副 万 户] 你需要标注的文本如下：
# 十六年，朝廷录其前后功，赐金虎符，授宣武将军、管军緑管，戍遂宁。十七年，进明威将军、管军副万户。
# PER：[]
# LOC：[遂宁]
# OFI：[朝廷, 宣武将军, 管军緑管, 戍遂宁, 明威将军, 管军副万户]
# {'PER': ['人名2', '李四'], 'LOC': ['遂宁', '地名2'], 'OFI': ['管军緑管', '朝廷', '戍遂宁', '宣武将军', '管军副万户', '宣 武 将 军', '明威将军', '戍 遂 宁', '管 军 副 万 户', '机构名2', '管 军 緑 管', '明 威 将 军', '朝 廷']}
# ['O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 子 伯 智 ， 八 岁 侍 学 东 宫 ， 十 岁 拜 太 子 洗 马 、 散 骑 侍 郎 。 尚 饶 阳 公 主 ， 拜 驸 马 都 尉 。 早 卒 。 子 喈 。
# PER：[子伯智, 子喈]
# LOC：[饶阳]
# OFI：[东宫, 太子, 驸马都尉] 该文本中的人名（PER）、地方的名字（LOC）、机构的名字（OFI）识别结果如下：
#
# PER：[子伯智, 子喈]
# LOC：[饶阳]
# OFI：[东宫, 太子, 驸马都尉]
#
# 解释：
# - "子伯智"和"子喈"是文本中出现的人名。
# - "饶阳"是文本中出现的地方名字。
# - "东宫"、"太子"和"驸马都尉"是文本中出现的机构名字。
# {'PER': ['子喈', '子伯智', '人名2', '李四'], 'LOC': ['饶阳', '地名2'], 'OFI': ['东宫', '机构名2', '太子', '驸马都尉']}
# ['B-PER', 'I-PER', 'E-PER', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'B-PER', 'E-PER', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 庚 戌 ， 陷 泗 州 ， 官 军 溃 。
# PER：
# LOC：[陷 �泗 州]
# OFI：[]
#
# 文本：庚 戌 ， 陷 泗 州 ， 官 军 溃 。
# PER：
# LOC：[陷 泗 州]
# OFI：[]
#
# 文本：庚 戌 ， 陷 泗 州 ， 官 军 溃 。
# PER：
# LOC：[陷 泗 州]
# OFI：[]
#
# 文本：庚 戌 ， 陷 泗 州 ， 官 军 溃 。
# PER：
# LOC：[陷 泗 州]
# OFI：[]
#
# 文本：庚 戌 ， 陷 泗 州 ， 官 军 溃 。
# PER：
# LOC：[陷 泗 州]
# OFI：[]
#
# 文本：庚 戌 ， 陷 泗 州 ， 官 军 溃 。
# PER：
# LOC：[陷 泗 州
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['机构名2']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 齐 朝 不 即 发 遣 ， 更 令 与 护 书 ， 要 护 重 报 ， 往 返 再 三 ， 而 母 竟 不 至 。 朝 议 以 其 失 信 ， 令 有 司 移 齐 曰 ：
# PER：[]
# LOC：[]
# OFI：[齐, 朝, 有司]
#
# 文本：齐朝并不派遣，更令与护书，要护重报，往返再三，而母竟不至。朝议以其失信，令有司移齐曰：
# PER：[]
# LOC：[]
# OFI：[齐, 朝]
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['朝', '机构名2', '齐', '有司']}
# ['S-OFI', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'S-OFI', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 初 ， 剑 南 度 茂 州 之 西 筑 安 戎 城 ， 以 迮 其 鄙 。 俄 为 生 羌 导 虏 取 之 以 守 ， 因 并 西 洱 河 诸 蛮 ， 尽 臣 羊 同 、 党 项 诸 羌 。 其 地 东 与 松 、 茂 、 巂 接 ， 南 极 婆 罗 门 ， 西 取 四 镇 ， 北 抵 突 厥 ， 幅 圆 馀 万 里 ， 汉 、 魏 诸 戎 所 无 也 。
# PER：[]
# LOC：[茂 巂, 婆 罗 门, 突 厥]
# OFI：[安 戎 城, 西 洱 河, 羊 同, 党 项, 松, 茂]
#
# 初 ， 剑 南 度 茂 州 之 西 筑 安 戎 城 ， 以 迮 其 鄙 。 俄 为 生 羌 导 虏 取 之 以 守 ， 因 并 西 洱 河 诸 蛮 ， 尽 臣 羊 同 、 党 项 诸 羌 。 其 地 东 与 松 、 茂 、 巂 接 ， 南 极 婆 罗 门 ， �
# {'PER': ['人名2', '李四'], 'LOC': ['婆 罗 门', '突 厥', '茂 巂', '地名2'], 'OFI': ['党 项', '羊 同', '茂', '安 戎 城', '西 洱 河', '机构名2', '松']}
# ['O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 李 彦 从 ， 字 士 元 ， 汾 州 孝 义 人 。 父 德 ， 麟 州 司 马 。 彦 从 少 习 武 艺 ， 出 行 伍 间 ， 高 祖 典 禁 军 ， 以 乡 里 之 旧 ， 任 为 亲 信 。 国 初 ， 用 为 左 飞 龙 使 、 检 校 司 空 。
# PER：[李 彦 从, 字 士 元]
# LOC：[汾 州, 孝 义, 麟 州]
# OFI：[高 祖, 国 初, 左 飞 龙 使, 检 校 司 空] 你找到的人名（PER）、地方的名字（LOC）和机构的名字（OFI）如下：
#
# 文本：李 彦 从 ， 字 士 元 ， 汾 州 孝 义 人 。 父 德 ， 麟 州 司 马 。 彦 从 少 习 武 艺 ， 出 行 伍 间 ， 高 祖 典 禁 军 ， 以 乡 里 之 旧 ， 任 为 亲 信 。 国 初 ， 用
# {'PER': ['字 士 元', '李 彦 从', '人名2', '李四'], 'LOC': ['汾 州', '麟 州', '孝 义', '地名2'], 'OFI': ['左 飞 龙 使', '国 初', '检 校 司 空', '机构名2', '高 祖']}
# ['B-PER', 'I-PER', 'E-PER', 'O', 'B-PER', 'I-PER', 'E-PER', 'O', 'B-LOC', 'E-LOC', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 兴 和 四 年 ， 从 高 祖 御 周 文 帝 于 邙 山 。 高 祖 身 在 行 间 ， 为 西 魏 将 贺 拔 胜 所 识 ， 率 锐 来 逼 。 韶 从 傍 驰 马 引 弓 反 射 ， 一 箭 毙 其 前 驱 ， 追 骑 慑 惮 ， 莫 敢 前 者 。 西 军 退 ， 赐 马 并 金 ， 进 爵 为 公 。
# PER：[高祖, 文帝, 贺拔胜, 韶]
# LOC：[行间, 邙山]
# OFI：[西魏, 西军] 以下是文本中的识别结果：
#
# PER：[高祖, 文帝, 贺拔胜, 韶]
# LOC：[行间, 邙山]
# OFI：[西魏, 西军] 以下是文本中的识别结果：
#
# PER：[高祖, 文帝, 贺拔胜, 韶]
# LOC：[行间, 邙山]
# OFI：[西魏, 西军]
# {'PER': ['高祖', '文帝', '贺拔胜', '韶', '人名2', '李四'], 'LOC': ['邙山', '行间', '地名2'], 'OFI': ['机构名2', '西军', '西魏']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'E-PER', 'O', 'O', 'B-PER', 'E-PER', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'B-PER', 'I-PER', 'E-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 三 月 ， 武 皇 进 军 渡 滹 沱 ， 攻 栾 城 ， 下 鼓 城 、 藁 城 。 四 月 ， 燕 军 寇 云 、 代 ， 武 皇 班 师 。
# PER：[武皇]
# LOC：[滹沱, 栾城, 鼓城, 藁城, 云, 代]
# OFI：[]
#
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：三 月 ， 武 皇 进 军 渡 滹 沱 ， 攻 栾 城 ， 下 鼓 城 、 藁 城 。 四 月 ， 燕 军 寇 云 、
# {'PER': ['武皇', '人名2', '李四'], 'LOC': ['栾城', '地名2', '云', '藁城', '滹沱', '鼓城', '代'], 'OFI': ['机构名2']}
# ['O', 'O', 'O', 'B-PER', 'E-PER', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-LOC', 'O', 'S-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 初 未 获 注 ， 京 师 忧 恐 。 至 是 ， 人 人 相 庆 。
# PER：[]
# LOC：[京, 师]
# OFI：[]
#
# 初 未 获 注 ， 京 师 忧 恐 。 至 是 ， 人 人 相 庆 。
# PER：[]
# LOC：[京, 师]
# OFI：[]
#
# 初 未 获 注 ， 京 师 忧 恐 。 至 是 ， 人 人 相 庆 。
# PER：[]
# LOC：[京, 师]
# OFI：[]
#
# 初 未 获 注 ， 京 师 忧 恐 。 至 是 ， 人 人 相 庆 。
# PER：[]
# LOC：[京, 师]
# OFI：[]
#
# 初 未 获 注 ， 京 师 忧 恐 。 至 是 ， 人 人 相 庆 。
# PER：[]
# LOC
# {'PER': ['人名2', '李四'], 'LOC': ['师', '京', '地名2'], 'OFI': ['机构名2']}
# ['O', 'O', 'O', 'O', 'O', 'S-LOC', 'S-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 不 得 其 人 则 乱 ， 新 都 迁 汉 鼎 ， 晋 氏 倾 魏 族 是 也 。 是 以 先 王 明 上 下 之 序 ， 圣 人 重 君 臣 之 分 。 委 质 同 于 股 肱 ， 受 爵 均 其 休 戚 。 当 其 亲 受 顾 讬 ， 位 居 宰 衡 ， 虽 复 承 利 剑 ， 临 沸 鼎 ， 不 足 以 讋 其 虑 ； 据 帝 图 ， 君 海 内 ， 不 足 以 回 其 心 。 若 斯 人 者 ， 固 以 功 与 山 岳 争 其 高 ， 名 与 穹 壤 齐 其 久 矣 。
# PER：[]
# LOC：[新都]
# OFI：[汉鼎, 晋氏, 先王, 圣人, 上下, 君臣, 股肱, 顾 讬, 宰衡, 帝图]
#
# 文本：不 得 其 人 则 乱 ， 新 都 迁 汉 鼎 ， 晋 氏 倾 魏 族 是 也 。 是 以 先 王 明 上 下 之 序 ， 圣 人 重 君 臣 之 分 。 委 质 同 于 股 肱 ， 受 爵 均 其 休 戚 。 当 其 亲 受 顾 讬 ， 位 居 宰 衡 ， 虽 复 承 利 剑 ， 临 �
# {'PER': ['人名2', '李四'], 'LOC': ['新都', '地名2'], 'OFI': ['先王', '顾 讬', '股肱', '君臣', '晋氏', '帝图', '圣人', '机构名2', '上下', '汉鼎', '宰衡']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 吐 蕃 遣 使 谢 ， 且 言 ： 「 唐 、 吐 蕃 皆 大 国 ， 今 约 和 为 久 长 计 ， 恐 边 吏 有 妄 意 者 ， 请 以 使 人 对 相 晓 敕 ， 令 昭 然 具 知 。 」
# PER：[]
# LOC：[吐蕃]
# OFI：[遣使, 谢, 唐, 吐蕃, 和, 边吏, 使, 敕]
#
# 文本：吐蕃遣使谢，且言：「唐、吐蕃皆大国，今约和为久长计，恐边吏有妄意者，请以使人为对相晓敕，令昭然具知。」
# PER：[]
# LOC：[吐蕃]
# OFI：[遣使, 谢, 唐, 吐蕃, 和, 边吏, 使, 敕]
# {'PER': ['人名2', '李四'], 'LOC': ['吐蕃', '地名2'], 'OFI': ['和', '吐蕃', '使', '遣使', '机构名2', '边吏', '敕', '唐', '谢']}
# ['B-OFI', 'E-OFI', 'B-OFI', 'E-OFI', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 赠 假 黄 钺 、 使 持 节 、 都 督 朔 并 定 赵 冀 沧 齐 兖 梁 洛 晋 建 十 二 州 诸 军 事 ， 相 国 、 太 尉 、 录 尚 书 事 、 朔 州 刺 史 ， 諡 曰 忠 武 。
# PER：
# LOC：
# OFI：[假, 使, 持, 节, 都, 督, 朔, 并, 定, 赵, 冀, 沧, 齐, 兖, 梁, 洛, 晋, 建, 十, 二, 州, 相, 国, 太, 尉, 录, 尚, 书, 事, 朔, 州, 刺, 史]
#
# PER：[]
# LOC：[朔, 并, 定, 赵, 冀, 沧, 齐, 兖, 梁, 洛, 晋]
# OFI：[假, 使, 节, 都, 督, 相, 国, 太, 尉, 录, 尚, 书
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['机构名2']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 出 为 北 镇 都 将 ， 征 拜 殿 中 尚 书 。 出 镇 凉 州 ， 所 在 著 称 。 还 加 散 骑 常 侍 ， 领 太 仓 尚 书 。
# PER：[]
# LOC：[北, 镇, 都, 凉, 州]
# OFI：[为, 征, 殿, 中, 尚, 书, 所, 在, 太, 仓, 尚, 书] 你标注的文本如下：
# 文本：出 为 北 镇 都 将 ， 征 拜 殿 中 尚 书 。 出 镇 凉 州 ， 所 在 著 称 。 还 加 散 骑 常 侍 ， 领 太 仓 尚 书 。
# PER：[]
# LOC：[北, 镇, 凉, 州]
# OFI：[为, 为, 征, 拜, 殿, 中, 尚, 书, 所, 在, 领, 太,
# {'PER': ['人名2', '李四'], 'LOC': ['镇', '北', '地名2', '州', '凉', '都'], 'OFI': ['征', '在', '太', '所', '殿', '书', '机构名2', '仓', '尚', '为', '中']}
# ['O', 'S-OFI', 'S-LOC', 'S-LOC', 'S-LOC', 'O', 'O', 'S-OFI', 'O', 'S-OFI', 'S-OFI', 'S-OFI', 'S-OFI', 'O', 'O', 'S-LOC', 'S-LOC', 'S-LOC', 'O', 'S-OFI', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'S-OFI', 'S-OFI', 'S-OFI', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 揣 帝 意 薄 承 干 ， 乃 为 王 谐 媚 用 事 臣 ， 数 言 王 聦 睿 可 为 嗣 ， 人 或 以 闻 ， 帝 隐 恚 。 及 王 贬 爵 ， 暴 其 罪 ， 以 如 晦 功 免 死 ， 废 于 家 ， 终 虔 化 令 。
# PER：[揣, 帝, 王]
# LOC：[]
# OFI：[承干, 王谐, 王, 嗣, 王, 晦, 家, 虔化令] 你的任务是识别给定文本中的人名（PER）、地方的名字（LOC）和机构的名字（OFI），并按照指定格式输出。
#
# 文本：揣 帝 意 薄 承 干 ， 乃 为 王 谐 媚 用 事 臣 ， 数 言 王 聰 睿 可 为 嗣 ， 人 或 以 闻 ， 帝 隐 恚 。 及 王 贬 爵 ， 暴 其 罪 ， 以 如 晦 功 免 死 ， 废 于 �
# {'PER': ['帝', '王', '揣', '人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['王', '王谐', '承干', '家', '机构名2', '虔化令', '嗣', '晦']}
# ['S-PER', 'S-PER', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'S-PER', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 凡 从 事 于 斯 者 ， 孰 不 能 乎 ！ 但 前 之 守 土 者 ， 不 能 如 是 ， 是 以 汝 民 咨 嗟 爱 慕 。 今 天 下 戎 马 之 后 ， 四 方 凶 盗 之 馀 ， 杼 轴 空 而 赋 敛 繁 ， 人 民 稀 而 仓 廪 匮 ， 谓 之 康 泰 ， 未 易 轻 言 。 侯 伯 牧 宰 ， 若 能 哀 矜 之 ， 不 至 聚 敛 ， 不 杀 无 辜 之 民 ， 民 为 邦 本 ， 政 为 民 本 ， 和 平 宽 易 ， 即 刘 君 之 政 安 足 称 耶 ！
# PER：[]
# LOC：[]
# OFI：[侯伯牧宰, 刘君] 你首先找出文本中的人名（PER）并列出。
# 文本：凡 从 事 于 斯 者 ， 孰 不 能 乎 ！ 但 前 之 守 土 者 ， 不 能 如 是 ， 是 以 汝 民 咨 嗟 爱 慕 。 今 天 下 戎 马 之 后 ， 四 方 凶 盗 之 馀 ， 杼 轴 空 而 赋 敛 繁 ， 人 民 稀 而 仓 廪 匮 ， 谓 之 康 泰 ， 未 易 轻 言 。 侯 伯 牧 宰 ， 若 能
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['侯伯牧宰', '机构名2', '刘君']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 李 怀 光 有 异 志 ， 欲 怒 其 军 使 叛 ， 即 上 言 ： 「 兵 禀 薄 ， 与 神 策 不 等 ， 难 以 战 。 」 李 晟 密 言 其 变 ， 因 请 移 屯 。 帝 遣 贽 见 怀 光 议 事 。 贽 还 奏 ： 「 怀 光 寇 奔 不 追 ， 师 老 不 用 ， 羣 帅 欲 进 ， 辄 沮 止 其 谋 。
# PER：[]
# LOC：[]
# OFI：[李怀光, 神策, 帝, 贽, 怀光, 奔, 贽]
#
# 文本：李怀光有异志，欲怒其军使叛，即上言：「兵禀薄，与神策不等，难以战。」李晟密言其变，因请移屯。帝遣贽见怀光议事。贽还奏：「怀光寇奔不追，师老不用，羣帅欲进，辄沮止其谋。
# PER：[]
# LOC：[]
# OFI：[李怀光, 神策, 帝, 贽, 怀光, 奔, 贽]  根据给出的文本，重新标注人名、地名和机构名：
#
# 文本：李怀光有异志，欲怒其军使叛，即上言：
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['帝', '贽', '神策', '怀光', '机构名2', '李怀光', '奔']}
# ['B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 贽 不 纳 ， 止 受 茶 一 串 ， 曰 ： 「 敢 不 承 公 之 赐 。 」 以 书 判 拔 萃 补 渭 南 尉 。
# PER：[]
# LOC：[]
# OFI：[贽, 拔萃, 渭南, 尉]
#
# 文本：贽 不 纳 ， 止 受 茶 一 串 ， 曰 ： 「 敢 不 承 公 之 赐 。 」 以 书 判 拔 萃 补 渭 南 尉 。
# PER：[]
# LOC：[]
# OFI：[贽, 拔萃, 渭南, 尉] 这个文本中的人名（PER）、地方的名字（LOC）、机构的名字（OFI）如下：
#
# PER：[]
# LOC：[渭南]
# OFI：[贽, 拔萃, 渭南, 尉]
# {'PER': ['人名2', '李四'], 'LOC': ['渭南', '地名2'], 'OFI': ['渭南', '尉', '贽', '机构名2', '拔萃']}
# ['S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'E-OFI', 'S-OFI', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 旣 得 行 其 志 ， 生 平 恩 雠 ， 丝 毫 必 报 。 因 杨 虞 卿 之 狱 ， 挟 忌 李 宗 闵 、 李 德 裕 ， 心 所 恶 者 ， 目 为 二 人 之 党 。 朝 士 相 继 斥 逐 ， 班 列 为 之 一 空 ， 人 人 惴 栗 ， 若 崩 厥 角 。 帝 微 知 之 ， 下 诏 慰 谕 ， 人 情 稍 安 。
# PER：[杨 虞 卿, 李 宗 闵, 李 德 裕, 帝]
# LOC：[]
# OFI：[杨 虞 卿 之 狱, 李 宗 闵, 李 德 裕, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人, 人
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['机构名2']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 干 统 初 ， 加 太 子 太 师 ， 为 国 舅 详 稳 。 二 年 ， 改 辽 兴 军 节 度 使 ， 召 为 北 府 宰 相 ， 以 柴 册 礼 ， 加 兼 侍 中 。
# PER：[]
# LOC：[辽]
# OFI：[太子太师, 辽兴军节度使, 北府宰相, 侍中] 你的任务是识别给定文本中的人名（PER）、地方的名字（LOC）和机构的名字（OFI），并按照指定格式输出。
#
# 文本：干 统 初 ， 加 太 子 太 师 ， 为 国 舅 详 稳 。 二 年 ， 改 辽 兴 军 节 度 使 ， 召 为 北 府 宰 相 ， 以 柴 册 礼 ， 加 兼 侍 中 。
# PER：[]
# LOC：[辽]
# OFI：[太子太师, 辽兴军节度使, 北府宰相, 侍中]
#
# 解析：
# 1. **人名（PER）**：文本中没有明确
# {'PER': ['人名2', '李四'], 'LOC': ['辽', '地名2'], 'OFI': ['侍中', '机构名2', '太子太师', '北府宰相', '辽兴军节度使']}
# ['O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 至 若 鲧 为 黄 熊 ， 杜 宇 为 鶗 鴃 ， 襃 君 为 龙 ， 牛 哀 为 兽 ， 君 子 为 鹄 ， 小 人 为 猿 ， 彭 生 为 豕 ， 如 意 为 犬 ， 黄 母 为 鼋 ， 宣 武 为 鼈 ， 邓 艾 为 牛 ， 徐 伯 为 鱼 ， 铃 下 为 乌 ，
# PER：[若, 鲧, 杜, 宇, 襃, 君, 牛, 哀, 君, 子, 小, 人, 彭, 生, 如, 意, 黄, 母, 宣, 武, 邓, 艾, 徐, 伯, 铃, 下]
# LOC：[无]
# OFI：[黄, 熊, 鶗, 鴃, 龙, 兽, 鹄, 猿, 豕, 鼈, 牛, 鱼, 乌, 鼋, 鼈, 牛, 鱼, 乌] 这段文本中：
# PER：[若, 鲧, 杜, 宇, 襃, 君, 牛, 哀, 君, 子, �
# {'PER': ['宣', '生', '艾', '徐', '伯', '君', '李四', '武', '铃', '彭', '小', '母', '如', '子', '襃', '黄', '人', '下', '杜', '牛', '鲧', '若', '宇', '邓', '哀', '人名2', '意'], 'LOC': ['无', '地名2'], 'OFI': ['鶗', '鹄', '熊', '豕', '兽', '鼈', '黄', '鴃', '龙', '机构名2', '牛', '鱼', '猿', '乌', '鼋']}
# ['O', 'S-PER', 'S-PER', 'O', 'S-OFI', 'S-OFI', 'O', 'S-PER', 'S-PER', 'O', 'S-OFI', 'S-OFI', 'O', 'S-PER', 'S-PER', 'O', 'S-OFI', 'O', 'S-OFI', 'S-PER', 'O', 'S-OFI', 'O', 'S-PER', 'S-PER', 'O', 'S-OFI', 'O', 'S-PER', 'S-PER', 'O', 'S-OFI', 'O', 'S-PER', 'S-PER', 'O', 'S-OFI', 'O', 'S-PER', 'S-PER', 'O', 'O', 'O', 'S-OFI', 'S-PER', 'O', 'S-OFI', 'O', 'S-PER', 'S-PER', 'O', 'S-OFI', 'O', 'S-PER', 'S-PER', 'O', 'S-OFI', 'O', 'S-PER', 'S-PER', 'O', 'S-OFI', 'O', 'S-PER', 'S-PER', 'O', 'S-OFI', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 是 岁 ， 诏 谕 ： 「 民 间 私 租 太 重 ， 以 十 分 为 率 普 减 二 分 ， 永 为 定 例 。 」 降 钞 十 万 锭 赏 江 西 守 城 官 吏 军 民 。 京 师 大 饥 ， 加 以 疫 疠 ， 民 有 父 子 相 食 者 。 帝 于 内 苑 造 龙 船 ， 委 内 官 供 奉 少 监 塔 思 不 花 监 工 。
# PER：[]
# LOC：[京师]
# OFI：[诏, 太, 江西, 守, 官, 军, 民, 京, 师, 大, 饥, 疫, 疫, 疫, 帝, 内, 苑, 龙, 船, 内, 官, 少, 监, 塔, 思, 不, 花, 监, 工] 标注结果如下：
#
# PER：[]
# LOC：[京师]
# OFI：[诏, 太, 江西, 守, 官, 军, 民, 京, 师]
# {'PER': ['人名2', '李四'], 'LOC': ['京师', '地名2'], 'OFI': ['饥', '内', '塔', '工', '花', '民', '师', '官', '守', '大', '帝', '疫', '江西', '太', '船', '龙', '军', '诏', '京', '苑', '少', '思', '监', '机构名2', '不']}
# ['O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'S-OFI', 'O', 'S-OFI', 'O', 'S-OFI', 'S-OFI', 'O', 'S-OFI', 'S-OFI', 'S-OFI', 'S-OFI', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'S-OFI', 'S-OFI', 'O', 'S-OFI', 'S-OFI', 'O', 'O', 'S-OFI', 'S-OFI', 'O', 'O', 'S-OFI', 'S-OFI', 'S-OFI', 'S-OFI', 'S-OFI', 'S-OFI', 'S-OFI', 'S-OFI', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 裕 宗 甚 爱 之 ， 谓 符 宝 郎 董 文 忠 曰 ： 「 汝 为 我 奏 请 ， 以 谅 所 管 民 户 隶 于 我 ， 庶 得 谅 尽 力 为 我 用 。 」 文 忠 入 奏 ， 帝 从 之 。 未 几 ， 授 谅 嘉 议 大 夫 ， 迁 兵 部 尚 书 。 卒 。
# PER：[]
# LOC：[]
# OFI：[裕宗, 符宝郎, 董文忠, 帝, 文忠, 嘉议大夫, 兵部尚书]
#
# 裕宗甚爱之，谓符宝郎董文忠曰：“汝为我奏请，以谅所管民户隶于我，庶得谅尽力为我用。”文忠入奏，帝从之。未几，授谅嘉议大夫，迁兵部尚书。卒。
# PER：[]
# LOC：[]
# OFI：[裕宗, 符宝郎, 董文忠, 帝, 文忠, 嘉议大夫, 兵部尚书]
#
# 裕宗甚爱之，谓符宝郎董文忠曰：“汝为我奏请，以谅所管民户隶于我，庶得谅尽力为我用。”文忠入奏，帝从之。未几，授
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['帝', '董文忠', '嘉议大夫', '兵部尚书', '裕宗', '机构名2', '符宝郎', '文忠']}
# ['B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'B-OFI', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 璠 二 年 七 月 出 为 河 南 尹 。 大 和 二 年 ， 以 本 官 权 知 东 都 选 。 十 月 ， 转 尚 书 右 丞 ， 勑 选 毕 入 朝 。 三 年 ， 改 吏 部 侍 郎 。 四 年 七 月 ， 拜 京 兆 尹 、 兼 御 史 大 夫 。
# PER：[]
# LOC：[河南, 东都, 京兆]
# OFI：[尚书右丞, 吏部侍郎, 京兆尹, 御史大夫]璠 二 年 七 月 出 为 河 南 尹 。 大 和 二 年 ， 以 本 官 权 知 东 都 选 。 十 月 ， 转 尚 书 右 丞 ， 勑 选 毕 入 朝 。 三 年 ， 改 吏 部 侍 郎 。 四 年 七 月 ， 拜 京 兆 尹 、 兼 御 史 大 夫 。
# PER：[]
# LOC：[河南, 东都, 京兆]
# OFI：[尚书右丞, 吏部侍郎, 京兆尹
# {'PER': ['人名2', '李四'], 'LOC': ['河南', '京兆', '东都', '地名2'], 'OFI': ['御史大夫', '京兆尹', '尚书右丞', '吏部侍郎', '机构名2']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 固 辞 太 子 太 傅 ， 见 听 。
# PER：
# LOC：
# OFI：
#
# PER：[太子, 太傅]
# LOC：
# OFI：[太子, 太傅] 固辞太子太傅，见听。
# PER：[]
# LOC：[]
# OFI：[太子, 太傅] 固辞太子太傅，见听。 这段文本中没有识别到任何具体的人名、地名或机构名，因此输出为：
# PER：[]
# LOC：[]
# OFI：[] 固辞太子太傅，见听。 固辞太子太傅，见听。 这段文本中没有识别到任何具体的人名、地名或机构名，因此输出为：
# PER：[]
# LOC：[]
# OFI：[] 固辞太子太傅，见听。 固辞太子太傅，见听。 这段文本中没有识别到任何具体的人名、地名或机构名，因此输出为：
# PER：[]
# LOC：[]
# OF
# {'PER': ['见听。\nPER：[', '太子', '太傅]\nLOC：\nOFI：[太子', '太傅] 固辞太子太傅', '人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['太傅', '机构名2', '太子']}
# ['O', 'O', 'B-OFI', 'E-OFI', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 奂 在 职 清 俭 ， 多 所 规 正 ， 宣 帝 嘉 之 ， 赐 米 五 百 斛 ， 并 累 降 敕 书 ， 殷 勤 劳 问 。
# PER：[]
# LOC：[清, 俭, 上海, 宣, 帝]
# OFI：[奂, 在, 职, 清, 俭, 宣, 帝, 米, 五, 百, 斛, 敕, 殷, 勤, 劳, 问] 请根据题目要求，逐句分析该文本：
#
# 1. "奂 在 职 清 俭 ， 多 所 规 正 ， 宣 帝 嘉 之 ， 赐 米 五 百 斛 ， 并 累 降 敕 书 ， 殷 勤 劳 问 。"
#    - PER: []
#    - LOC: [宣, 帝]
#    - OFI: [奂, 在, 职, 清, 俭, 宣, 帝, �
# {'PER': ['人名2', '李四'], 'LOC': ['帝', '宣', '地名2', '俭', '清', '上海'], 'OFI': ['帝', '米', '在', '宣', '奂', '五', '俭', '职', '百', '殷', '勤', '问', '机构名2', '清', '敕', '劳', '斛']}
# ['S-OFI', 'S-OFI', 'S-OFI', 'S-OFI', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'S-OFI', 'O', 'O', 'O', 'O', 'S-OFI', 'S-OFI', 'S-OFI', 'S-OFI', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'S-OFI', 'S-OFI', 'S-OFI', 'S-OFI', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 甲 戌 ， 授 宣 抚 使 ， 兼 行 尚 书 六 部 事 。 从 三 合 拔 都 、 太 傅 猛 安 率 兵 南 征 ， 下 古 北 口 ， 攻 蓟 、 云 、 顺 等 州 ， 所 过 迎 降 ， 得 汉 军 数 万 ， 遂 围 中 都 。 乙 亥 ， 中 都 降 。
# PER：[甲 戌]
# LOC：[古 北 口, 中 都]
# OFI：[宣 抚 使, 行 尚 书 六 部 事, 从 三, 合 拔, 太 傅, 猛 安, 中 都] 甲 戌 ， 授 宣 抚 使 ， 兼 行 尚 书 六 部 事 。 从 三 合 拔 都 、 太 傅 猛 安 率 兵 南 征 ， 下 古 北 口 ， 攻 蓟 、 云 、 顺 等 州 ， 所 过 迎 降 ， 得 汉 军 数 万 ， 遂 围 中 都 。 乙 亥 ， 中 都 降
# {'PER': ['甲 戌', '人名2', '李四'], 'LOC': ['古 北 口', '中 都', '地名2'], 'OFI': ['中 都', '行 尚 书 六 部 事', '宣 抚 使', '太 傅', '猛 安', '机构名2', '合 拔', '从 三']}
# ['B-PER', 'E-PER', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'B-OFI', 'E-OFI', 'B-OFI', 'E-OFI', 'O', 'O', 'B-OFI', 'E-OFI', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 淳 少 好 学 ， 有 美 名 ， 历 中 书 黄 门 侍 郎 。 黄 门 清 切 ， 直 下 应 留 下 省 ， 以 父 老 特 听 还 家 。 高 简 寡 言 ， 早 有 清 尚 ， 爱 好 文 义 ， 未 尝 违 舍 。 在 祕 书 阁 撰 四 部 书 大 目 ， 凡 四 十 卷 ， 行 于 世 。 元 嘉 十 一 年 卒 ， 朝 廷 痛 惜 之 。
# PER：[淳]
# LOC：[]
# OFI：[少学, 中书黄门侍郎, 黄门, 应留省, 祕书阁]
#
# 文本：淳少好学，有美名，历中书黄门侍郎。黄门清切，直下应留省，以父老特听还家。高简寡言，早有清尚，爱好文义，未尝违舍。在秘书阁撰四部书大目，凡四十卷，行于世。元嘉十一年卒，朝廷痛惜之。
# PER：[淳]
# LOC：[]
# OFI：[少学, 中书黄门侍郎, 黄门, 应留省, 祕书阁]
# {'PER': ['淳', '人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['应留省', '祕书阁', '少学', '黄门', '机构名2', '中书黄门侍郎']}
# ['S-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 又 谓 亮 曰 ： 「 徐 州 表 给 归 化 人 禀 。 王 者 民 之 父 母 ， 诚 宜 许 之 。 但 今 荆 扬 不 宾 ， 书 轨 未 一 ， 方 欲 亲 御 六 师 ， 问 罪 江 介 。 计 万 户 投 化 ， 岁 食 百 万 ， 若 听 其 给 也 ， 则 蕃 储 虚 竭 。 虽 得 户 千 万 ， 犹 未 成 一 同 。 且 欲 随 贫 赈 恤 ， 卿 意 何 如 ？ 」 亮 对 曰 ： 「 所 存 远 大 ， 实 如 圣 旨 。 」
# PER：[]
# LOC：[徐州, 江介, 荆扬]
# OFI：[表给归化人禀, 王者民之父母, 亲御六师, 问罪江介, 蕃储虚竭, 贫赈恤]
#
# 文本：徐州表给归化人禀。王者民之父母，诚宜许之。但今荆扬不宾，书轨未一，方欲亲御六师，问罪江介。计万户投化，岁食百万，若听其给也，则蕃储虚竭。虽得户千万，犹未成一统。且欲随贫赈恤，卿意如何？
# PER：[]
# LOC：[徐州, 江介, 荆扬]
# OFI：[表给归化人禀, 王者民之父母, 亲御六师, 问罪江介, 蕃
# {'PER': ['人名2', '李四'], 'LOC': ['江介', '荆扬', '徐州', '地名2'], 'OFI': ['贫赈恤', '王者民之父母', '蕃储虚竭', '机构名2', '亲御六师', '表给归化人禀', '问罪江介']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'B-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 宋 幼 主 既 降 ， 其 相 陈 宜 中 等 挟 二 王 逃 闽 、 广 ， 所 在 扇 惑 ， 民 争 应 之 。 蕲 州 寇 起 司 空 山 ， 鄂 属 县 民 傅 高 亦 起 兵 应 。 居 贞 移 檄 谕 以 祸 福 ， 其 下 往 往 涣 散 ， 压 以 官 军 ， 遂 削 平 之 。 高 变 姓 名 逃 逸 ， 获 而 戮 之 。
# PER：[宋, 幼, 主, 陈, 宜, 中, 高]
# LOC：[上海, 闽, 广, 蕲, 州, 山, 鄂, 属, 县]
# OFI：[司空, 山, 居, 贞, 谕, 官, 军, 居, 贞, 戮] 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER
# {'PER': ['主', '高', '宋', '宜', '陈', '中', '人名2', '幼', '李四'], 'LOC': ['闽', '属', '地名2', '山', '州', '广', '县', '鄂', '蕲'], 'OFI': ['官', '谕', '山', '机构名2', '贞', '居', '军', '司空', '戮']}
# ['S-PER', 'S-PER', 'S-PER', 'O', 'O', 'O', 'O', 'O', 'S-PER', 'S-PER', 'S-PER', 'O', 'O', 'O', 'O', 'O', 'S-LOC', 'O', 'S-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-LOC', 'S-LOC', 'O', 'O', 'B-OFI', 'E-OFI', 'S-OFI', 'O', 'S-LOC', 'S-LOC', 'S-LOC', 'O', 'O', 'S-PER', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'S-OFI', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'S-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 庚 寅 ， 从 征 关 中 ， 长 驱 入 京 兆 ， 进 克 凤 翔 ， 请 于 太 宗 曰 ： 「 此 臣 乡 邦 也 ， 愿 入 城 访 求 亲 族 。 」 果 得 族 人 数 十 口 以 归 。 壬 辰 ， 从 攻 汴 京 。 癸 巳 ， 奉 命 持 国 书 使 宋 ， 以 兀 鲁 剌 副 之 。 至 宋 ， 宋 人 甚 礼 重 之 ， 即 遣 使 以 金 币 入 贡 。
# PER：[]
# LOC：[关 中, 京 兆, 凤 翔, 太 宗, 汴 京, 宋]
# OFI：[关 中, 京 兆, 凤 翔, 太 宗, 奉 命, 国, 汴 京, 宋]
#
# 文本：庚 寅 ， 从 征 关 中 ， 长 驱 入 京 兆 ， 进 克 凤 翔 ， 请 于 太 宗 曰 ： 「 此 臣 乡 邦 也 ， 愿 入 城 访 求 亲 族 。 」 果 得 族 人 数 十 口 以 归 。 壬 辰 ， 从 攻 汴 京 。 癸 巳 ， 奉 �
# {'PER': ['人名2', '李四'], 'LOC': ['关 中', '地名2', '凤 翔', '宋', '太 宗', '京 兆', '汴 京'], 'OFI': ['关 中', '凤 翔', '国', '宋', '太 宗', '奉 命', '机构名2', '京 兆', '汴 京']}
# ['O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'S-OFI', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 是 月 ， 会 州 、 定 西 、 静 宁 、 庄 浪 等 州 地 震 。 命 江 浙 行 省 左 丞 帖 里 帖 木 儿 、 江 南 行 台 侍 御 史 左 荅 纳 失 里 招 谕 方 国 珍 。
# PER：[]
# LOC：[会州, 定西, 静宁, 庄浪, 行省, 江浙, 江南, 方国珍]
# OFI：[会州, 定西, 静宁, 庄浪, 行省, 江浙, 江南, 侍御史, 左丞帖里, 帖木儿, 左, 荳纳失里, 方国珍] 你找出的人名（PER）、地方的名字（LOC）、机构的名字（OFI）如下：
#
# PER：[]
# LOC：[会州, 定西, 静宁, 庄浪, 江浙, 江南]
# OFI：[会州, 定西, 静宁, 庄浪, 行省, 江浙, 侍御史, 左丞帖里, �
# {'PER': ['人名2', '李四'], 'LOC': ['定西', '江南', '庄浪', '静宁', '地名2', '会州', '江浙', '方国珍', '行省'], 'OFI': ['定西', '侍御史', '江南', '庄浪', '静宁', '会州', '左', '荳纳失里', '江浙', '方国珍', '机构名2', '行省', '左丞帖里', '帖木儿']}
# ['O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'B-OFI', 'E-OFI', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 昭 祖 威 顺 皇 后 生 景 祖 ， 次 曰 乌 古 出 。 次 室 达 胡 末 ， 乌 萨 扎 部 人 ， 生 跋 黑 、 仆 里 黑 、 斡 里 安 。 次 室 高 丽 人 ， 生 胡 失 荅 。
# PER：[]
# LOC：[高丽]
# OFI：[昭祖, 威顺皇后, 景祖, 乌古出, 达胡末, 乌萨扎部, 跋黑, 仆里黑, 斡里安, 胡失葛]
#
# 文本：昭 祖 威 顺 皇 后 生 景 祖 ， 次 曰 乌 古 出 。 次 室 达 胡 末 ， 乌 萨 扎 部 人 ， 生 跋 黑 、 仆 里 黑 、 斡 里 安 。 次 室 高 丽 人 ， 生 胡 失 荔 。
# PER：[]
# LOC：[高丽]
# OFI：[昭祖, 威顺皇后, 景祖, 乌
# {'PER': ['人名2', '李四'], 'LOC': ['高丽', '地名2'], 'OFI': ['乌古出', '乌萨扎部', '斡里安', '跋黑', '仆里黑', '机构名2', '达胡末', '胡失葛', '景祖', '昭祖', '威顺皇后']}
# ['B-OFI', 'E-OFI', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 旧 作 解 里 ， 今 改 。
# PER：
# LOC：
# OFI： PER： []
# LOC：[]
# OFI：[]
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['机构名2']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 岁 癸 丑 ， 高 丽 权 臣 高 令 公 叛 ， 宪 宗 命 耶 虎 大 王 东 征 ， 綧 奉 旨 为 使 讲 和 ， 仍 镇 守 其 地 ， 时 高 丽 人 户 新 附 者 ， 就 命 綧 緫 之 。 中 统 元 年 ， 授 金 符 緫 管 ， 陞 佩 虎 符 ， 兼 领 军 民 。 三 年 ， 率 兵 征 济 南 李 璮 。
# PER：[高令公, 耶虎大王, 綧緫, 綧緫]
# LOC：[高丽, 济南]
# OFI：[宪宗, 中统, 金符緫] 以下是文本中的人名（PER）、地方的名字（LOC）、机构的名字（OFI）：
#
# 文本：岁 癸 丑 ， 高 丽 权 臣 高 令 公 叛 ， 宪 宗 命 耶 虎 大 王 东 征 ， 綧 奉 旨 为 使 讲 和 ， 仍 镇 守 其 地 ， 时 高 丽 人 户 新 附 者 ， 就 命 綧 緫 之 。 中 统 元 年 ， 授 金 符 緫 管
# {'PER': ['高令公', '耶虎大王', '綧緫', '人名2', '李四'], 'LOC': ['济南', '高丽', '地名2'], 'OFI': ['中统', '宪宗', '机构名2', '金符緫']}
# ['O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'B-PER', 'I-PER', 'E-PER', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'B-PER', 'I-PER', 'I-PER', 'E-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'E-PER', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 江 陞 为 武 卫 亲 军 都 指 挥 使 ， 赐 虎 符 ， 寻 改 属 左 卫 。 至 元 八 年 ， 从 攻 襄 阳 ， 殁 于 阵 ， 郇 袭 其 职 。
# PER：[江 陞, 李四]
# LOC：[襄 阳]
# OFI：[武 卫 亲 军 都 指 指 挥 使, 左 卫, 襄 阳]
#
# 江 陞 为 武 卫 亲 军 都 指 指 挥 使 ， 赐 虎 符 ， 寻 改 属 左 卫 。 至 元 八 年 ， 从 攻 襄 阳 ， 殁 于 阵 ， 郇 袭 其 职 。
# PER：[江 陞, 李四]
# LOC：[襄 阳]
# OFI：[武 卫 亲 军 都 指 指 挥 使, 左 卫, 襄 阳
# {'PER': ['江 陞', '人名2', '李四'], 'LOC': ['襄 阳', '地名2'], 'OFI': ['武 卫 亲 军 都 指 指 挥 使', '机构名2', '襄 阳', '左 卫']}
# ['B-PER', 'E-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 帝 又 令 金 吾 将 军 李 佺 监 赤 岭 树 碑 ， 诏 张 守 珪 与 将 军 李 行 祎 、 吐 蕃 使 者 莽 布 支 分 谕 剑 南 、 河 西 州 县 曰 「 自 今 二 国 和 好 ， 无 相 侵 暴 。 」
# PER：[李佺, 李行禎, 莽布支]
# LOC：[]
# OFI：[金吾将军, 赤岭, 剑南州, 河西州, 剑南, 河西]
#
# 帝 又 令 金 吾 将 军 李 佺 监 赤 岭 树 碑 ， 诏 张 守 珪 与 将 军 李 行 祎 、 吐 蕃 使 者 莽 布 支 分 谕 剑 南 、 河 西 州 县 曰 「 自 今 二 国 和 好 ， 无 相 侵 暴 。 」
# PER：[李佺, 李行禎, 莽布支]
# LOC：[]
# OF
# {'PER': ['李行禎', '李佺', '莽布支', '人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['赤岭', '金吾将军', '机构名2', '剑南', '河西州', '河西', '剑南州']}
# ['O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'B-PER', 'E-PER', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'E-PER', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'E-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 使 天 下 闻 之 ， 廓 然 一 变 ， 人 人 得 其 所 欲 ， 安 有 不 服 哉 ？ 其 须 改 革 科 条 ， 已 别 封 上 。 臣 闻 知 过 非 难 ， 改 之 难 ； 言 善 非 难 ， 行 之 难 。 易 曰 ： 『 圣 人 感 人 心 而 天 下 和 平 。 』 夫 感 者 ， 诚 发 于 心 ， 而 形 于 事 ， 事 或 未 谕 ， 故 宣 之 于 言 ， 言 必 顾 心 ， 心 必 副 事 ， 三 者 相 合 ， 乃 可 求 感 。
# PER：[]
# LOC：[]
# OFI：[天 下, 上, 科 条, 上, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天 下, 天
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['机构名2']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 以 功 授 开 府 。 仍 为 大 将 军 尉 迟 迥 长 史 ， 率 兵 伐 蜀 。 既 入 剑 阁 ， 迥 令 协 行 潼 州 事 。
# PER：[]
# LOC：[剑阁, 潼州]
# OFI：[开府, 大将军, 尉迟, 长史] 该文本中的人名（PER）、地方的名字（LOC）、机构的名字（OFI）如下：
#
# PER：[]
# LOC：[剑阁, 潼州]
# OFI：[开府, 大将军, 尉迟, 长史]
#
# 文本：以 功 授 开 府 。 仍 为 大 将 军 尉 迟 迥 长 史 ， 率 兵 伐 蜀 。 既 入 剑 阎 ， 迥 令 协 行 潼 州 事 。
# PER：[]
# LOC：[剑阎, 潼州]
# OFI：[开府, 大将军, 尉迟, 长史] 该文本中
# {'PER': ['人名2', '李四'], 'LOC': ['剑阎', '潼州', '剑阁', '地名2'], 'OFI': ['大将军', '尉迟', '机构名2', '开府', '长史']}
# ...
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 请 称 疾 ， 上 必 临 问 ， 可 以 得 志 。 」 及 败 ， 坐 诛 。 临 刑 ， 意 象 轩 骜 。 构 以 累 贬 死 岭 表 。
# PER：[]
# LOC：[]
# OFI：[轩 骜, 累 贬 死 岭 表] 请找出文本中的人名（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：请 称 疾 ， 上 必 临 问 ， 可 以 得 志 。 」 及 败 ， 坐 诛 。 临 刑 ， �
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['轩 骜', '机构名2', '累 贬 死 岭 表']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 其 三 帅 部 内 太 原 、 凤 翔 等 府 及 诸 郡 户 口 稍 多 者 ， 慎 拣 良 吏 以 为 尹 守 ， 外 奉 师 律 ， 内 课 农 桑 ， 俾 为 军 粮 ， 以 壮 戎 府 。 理 兵 之 宜 旣 得 ， 选 帅 之 授 旣 明 ， 然 后 减 奸 滥 虚 浮 之 费 以 丰 财 ， 定 衣 粮 等 级 之 制 以 和 众 ， 弘 委 任 之 道 以 宣 其 用 ， 悬 赏 罚 之 典 以 考 其 成 。
# PER：[]
# LOC：[太 原, 凤 翔, 诸 郡]
# OFI：[其 三 帅 部] 答案：
# PER：[]
# LOC：[太 原, 凤 翔, 诸 郡]
# OFI：[其 三 帅 部]
# {'PER': ['人名2', '李四'], 'LOC': ['凤 翔', '诸 郡', '太 原', '地名2'], 'OFI': ['其 三 帅 部', '机构名2']}
# ['B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'B-LOC', 'E-LOC', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 匹 夫 之 贱 ， 犹 不 自 轻 ， 况 万 乘 之 尊 ， 含 生 所 仰 ， 而 可 忽 乎 ！ 是 故 处 则 深 宫 广 厦 ， 行 则 万 骑 千 乘 。 昔 汉 帝 欲 乘 舟 渡 渭 ， 广 德 将 以 首 血 污 车 轮 ， 帝 乃 感 而 就 桥 。 夫 一 渡 小 水 ， 犹 尚 若 斯 ， 况 洪 河 浩 汗 ， 有 不 测 之 虑 。
# PER：[]
# LOC：[渭]
# OFI：[广德, 舟, 渭, 河]
#
# 匹 夫 之 贱 ， 犹 不 自 轻 ， 况 万 乘 之 尊 ， 含 生 所 仰 ， 而 可 忽 乎 ！ 是 故 处 则 深 宫 广 厦 ， 行 则 万 骑 千 乘 。 昔 汉 帝 欲 乘 舟 渡 渭 ， 广 德 将 以 首 血 污 车 轮 ， 帝 乃 感 而 就 桥 。 夫 一 渡 小 水 ， 犹 尚 若 斯 ， 况 洪 河 浩 �
# {'PER': ['人名2', '李四'], 'LOC': ['渭', '地名2'], 'OFI': ['河', '舟', '渭', '机构名2', '广德']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'S-OFI', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 子 宽 ， 大 将 军 、 长 乐 郡 公 ， 先 迥 卒 。 宽 兄 谊 ， 开 府 、 资 中 郡 公 。 宽 弟 顺 ， 以 迥 平 蜀 功 ， 授 开 府 、 安 固 郡 公 。
# PER：[子 宽, 大 将军, 长 乐 郡 公, 先 迥, 谊, 开 府, 资 中 郡 公, 顺, 迥, 安 固 郡 公]
# LOC：[长 乐 郡, 资 中 郡, 安 固 郡]
# OFI：[大 将军, 长 乐 郡 公, 先 迥, 谊, 开 府, 资 中 郡 公, 顺, 迥, 安 固 郡 公] 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI
# {'PER': ['迥', '顺', '子 宽', '长 乐 郡 公', '大 将军', '安 固 郡 公', '谊', '开 府', '资 中 郡 公', '先 迥', '人名2', '李四'], 'LOC': ['长 乐 郡', '安 固 郡', '资 中 郡', '地名2'], 'OFI': ['迥', '顺', '大 将军', '长 乐 郡 公', '安 固 郡 公', '谊', '机构名2', '开 府', '资 中 郡 公', '先 迥']}
# ['B-PER', 'E-PER', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 每 蕃 戎 一 警 ， 则 中 外 咸 震 ， 致 陛 下 有 旰 食 轸 怀 之 忧 ， 斯 乃 臣 等 居 大 官 、 受 重 寄 者 之 深 责 也 。 虽 承 诏 发 卒 ， 心 驰 寇 廷 ， 期 于 为 国 讨 除 ， 使 戎 人 芟 剪 。 昼 夜 思 忖 ， 何 补 涓 毫 ？ 所 以 慺 慺 愚 心 ， 愿 陈 万 一 。 臣 观 自 古 长 策 ， 昭 然 可 征 。
# PER：[]
# LOC：[]
# OFI：[蕃，戎，中外，陛，大，寇，戎，国，毫，万，古] 你找出的人名（PER）、地方的名字（LOC）、机构的名字（OFI）如下：
#
# 文本：每 蕃 戎 一 警 ， 则 中 外 咸 震 ， 致 陛 下 有 旰 食 轸 怀 之 忧 ， 斯 乃 臣 等 居 大 官 、 受 重 寄 者 之 深 责 也 。 虽 承 诏 发 卒 ， 心 驰 寇 廷 ， 期 于 为 国 讨 除 ， 使 戎 人 芟 剪 。 昼 夜 思 忖 ， 何 补 �
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['寇', '中外', '古', '国', '戎', '毫', '万', '蕃', '机构名2', '陛', '大']}
# ['O', 'S-OFI', 'S-OFI', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 运 乃 舆 榇 诣 朝 堂 ， 陈 帝 八 失 ：
# PER：[]
# LOC：[朝 堂]
# OFI：[运 乃 舆 榉, 陈 帝]
#
# 文本：运 乃 舆 榉 诣 朝 堂 ， 陈 帝 八 失 ：
# PER：[]
# LOC：[朝 堂]
# OFI：[运 乃 舆 榉, 陈 帝]
# {'PER': ['人名2', '李四'], 'LOC': ['朝 堂', '地名2'], 'OFI': ['陈 帝', '机构名2', '运 乃 舆 榉']}
# ['O', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 时 与 王 华 、 王 昙 首 、 刘 湛 四 人 并 为 侍 中 ， 以 风 力 局 干 ， 冠 冕 一 时 ， 同 升 之 美 ， 近 代 莫 及 。 元 嘉 三 年 ， 车 驾 征 谢 晦 ， 司 徒 王 弘 入 居 中 书 下 省 ， 景 仁 长 直 ， 共 掌 留 任 。
# PER：[]
# LOC：[]
# OFI：[王华, 王昙首, 刘湛, 侍中, 风力局, 冠冕, 谢晦, 王弘, 中书下省, 景仁长直] 你找出的人名（PER）、地方的名字（LOC）、机构的名字（OFI）如下：
#
# PER：[]
# LOC：[]
# OFI：[王华, 王昙首, 刘湛, 侍中, 风力局, 冠冕, 谢晦, 王弘, 中书下省, 景仁长直]
#
# 这个文本中没有直接提到人名、地名或机构名。因此，所有PER、LOC和OFI的输出均为空列表。
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['刘湛', '侍中', '景仁长直', '王昙首', '中书下省', '风力局', '机构名2', '王弘', '王华', '冠冕', '谢晦']}
# ['O', 'O', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 再 荣 贪 昧 无 决 ， 举 止 多 疑 ， 出 入 骑 从 ， 露 刃 注 矢 ， 诸 校 不 相 统 摄 ， 互 有 猜 贰 。 奉 国 厢 主 王 饶 惧 为 再 荣 所 并 ， 乃 据 东 门 楼 ， 以 兵 自 衞 ， 伪 称 足 疾 ， 不 敢 见 再 荣 。
# PER：[王饶]
# LOC：[]
# OFI：[再荣, 国厢, 东门楼, 诸校]
#
# 再 荣 贪 昧 无 决 ， 举 止 多 疑 ， 出 入 骑 从 ， 露 刃 注 矢 ， 诸 校 不 相 统 摄 ， 互 有 猜 贰 。 奉 国 厢 主 王 饶 惧 为 再 荣 所 并 ， 乃 据 东 门 楼 ， 以 兵 自 衛 ， 伪 称 足 疾 ， 不 敢 见 再 荣 。
# PER：[再荣, 王饶]
# LOC：[]
# OFI：[国厢, 东门楼]
# {'PER': ['王饶', '再荣', '人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['东门楼', '再荣', '国厢', '诸校', '机构名2']}
# ['B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'B-PER', 'E-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 楫 前 后 凡 五 往 ， 以 和 议 未 决 ， 隐 忧 致 疾 ， 卒 干 南 。 宋 人 重 赗 之 ， 仍 遣 使 归 其 柩 ， 葬 于 燕 。 子 六 人 。
# PER：[]
# LOC：[燕]
# OFI：[宋] 标注结果如下：
#
# 文本：楫 前 后 凡 五 往 ， 以 和 议 未 决 ， 隐 忧 致 疾 ， 卒 干 南 。 宋 人 重 赗 之 ， 仍 遣 使 归 其 柩 ， 葬 于 燕 。 子 六 人 。
# PER：[]
# LOC：[南, 燕]
# OFI：[宋]
# {'PER': ['人名2', '李四'], 'LOC': ['燕', '南', '地名2'], 'OFI': ['机构名2', '宋']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-LOC', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-LOC', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 及 帝 疾 笃 ， 奂 与 宣 帝 及 到 仲 举 并 吏 部 尚 书 袁 枢 、 中 书 舍 人 刘 师 知 等 入 侍 医 药 。
# PER：[到 仲 举, 刘 师 知]
# LOC：[]
# OFI：[帝, 宣 帝, 袁 枢, 中 书 舍 人, 刘 师 知, 吏 部 尚 书] 。
# PER：[到 仲 举, 刘 师 知]
# LOC：[]
# OFI：[帝, 宣 帝, 袁 枢, 中 书 舍 人, 刘 师 知, 吏 部 尚 书] 。
# {'PER': ['刘 师 知', '到 仲 举', '人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['帝', '宣 帝', '袁 枢', '刘 师 知', '机构名2', '中 书 舍 人', '吏 部 尚 书']}
# ['O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'B-PER', 'I-PER', 'E-PER', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 礼 弟 略 ， 武 定 末 ， 魏 尹 丞 。
# PER：
# LOC：
# OFI：
#
# PER：[礼, 弟, 略, 武, 定, 魏, 尹]
# LOC：
# OFI：[]
#
# 文本：礼 弟 略 ， 武 定 末 ， 魏 尹 丞 。
# PER：[礼, 弟, 略, 武, 定, 魏, 尹]
# LOC：
# OFI：[]
#
# 文本：礼 弟 略 ， 武 定 末 ， 魏 尹 丞 。
# PER：[礼, 弟, 略, 武, 定, 魏, 尹]
# LOC：
# OFI：[]
#
# 文本：礼 弟 略 ， 武 定 末 ， 魏 尹 丞 。
# PER：[礼, 弟, 略, 武, 定, 魏,
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['机构名2']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 晋 天 福 二 年 夏 ， 范 延 光 叛 于 邺 ， 牙 将 孙 锐 率 兵 至 黎 阳 ， 朝 廷 遣 侍 衞 马 军 都 指 挥 使 白 奉 进 领 兵 渡 滑 州 ， 万 亦 预 其 行 。 时 滑 州 节 度 使 符 彦 饶 潜 通 邺 下 ， 杀 白 奉 进 于 牙 署 。
# PER：[范 延 光, 孙 锐, 白 奉 进, 符 彦 饶]
# LOC：[邺, 黎 阳, 滑 州, 邺]
# OFI：[牙 将, 朝 廷, 侍 衞 马 军 都 指 挥 使, 滑 州 节 度 使] 你找到的文本信息如下：
#
# PER：[范 延 光, 孙 锐, 白 奉 进, 符 彦 饶]
# LOC：[邺, 黎 阳, 滑 州, 邺]
# OFI：[牙 将, 朝 廷, 侍 衫 马 军 都 指 挥 使, 滑 州 �
# {'PER': ['孙 锐', '白 奉 进', '符 彦 饶', '范 延 光', '人名2', '李四'], 'LOC': ['邺', '滑 州', '黎 阳', '地名2'], 'OFI': ['侍 衞 马 军 都 指 挥 使', '机构名2', '牙 将', '滑 州 节 度 使', '朝 廷']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'E-PER', 'O', 'O', 'S-LOC', 'O', 'B-OFI', 'E-OFI', 'B-PER', 'E-PER', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'B-PER', 'I-PER', 'E-PER', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'B-PER', 'I-PER', 'E-PER', 'O', 'O', 'S-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 训 旣 作 相 ， 以 守 澄 为 六 军 十 二 卫 观 军 容 使 ， 罢 其 禁 旅 之 权 ， 寻 赐 酖 杀 之 。 训 愈 承 恩 顾 ， 每 别 殿 奏 对 ， 他 宰 相 莫 不 顺 成 其 言 ， 黄 门 禁 军 迎 拜 戢 敛 。
# PER：[训]
# LOC：[]
# OFI：[相, 澄, 十二卫, 观军容使, 禁旅, 殿, 黄门, 禁军]
#
# 训 旣 作 相 ， 以 守 澄 为 六 军 十 二 卫 观 军 容 使 ， 罢 其 禁 旅 之 权 ， 寻 赐 酖 杀 之 。 训 愈 承 恩 顾 ， 每 别 殿 奏 对 ， 他 宰 相 莫 不 顺 成 其 言 ， 黄 门 禁 军 迎 拜 戢 敛 。
# PER：[训]
# LOC：[]
# OFI：[相, 澄, 十二卫,
# {'PER': ['人名2', '训', '李四'], 'LOC': ['地名2'], 'OFI': ['禁军', '观军容使', '黄门', '澄', '禁旅', '殿', '十二卫', '机构名2', '相']}
# ['S-PER', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'B-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'S-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'E-OFI', 'B-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 赜 与 洛 阳 元 善 、 河 东 柳 [ 巩 言 ， 凡 改 几 ] 、 太 原 王 劭 、 吴 兴 姚 察 、 琅 邪 诸 葛 颍 、 信 都 刘 焯 、 河 间 刘 炫 相 善 ， 每 因 休 假 ， 清 谈 竟 日 。
# PER：[]
# LOC：[洛 阳, 吴 兴, 琅 邪, 河 间]
# OFI：[元 善, 河 东 柳 [ 巩 言 ， 凡 改 几 ], 太 原 王 劝, 吴 兴 姚 察, 诸 葛 颍, 信 都 刘 焯, 河 间 刘 炫] 标注结果如下：
#
# PER：[]
# LOC：[洛 阳, 信 都]
# OFI：[元 善, 河 东 柳 [ 巩 言 ， 凡 改 几 ], 太 原 王 劝, 吴 兴 姚 察, 诸 葛 颍, 河 间 刘 �
# {'PER': ['人名2', '李四'], 'LOC': ['地名2', '河 间', '洛 阳', '琅 邪', '信 都', '吴 兴'], 'OFI': ['河 东 柳 [ 巩 言', '机构名2', '元 善', '凡 改 几']}
# ['O', 'O', 'B-LOC', 'E-LOC', 'B-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'I-OFI', 'E-OFI', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'B-LOC', 'E-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 请识别以下文本中的人的名字（PER）、地方的名字（LOC）、机构的名字（OFI）。输出格式为：
# PER：[人名1, 人名2]
# LOC：[地名1, 地名2]
# OFI：[机构名1, 机构名2]
#
# 首先请找出文本中的人名（PER）并列出。
# 其次找出地方名称（LOC）并列出。
# 最后找出机构名称（OFI）并列出。
#
# 示例：
# 文本：张三去了北京的清华大学。
# PER：[张三]
# LOC：[北京]
# OFI：[清华大学]
#
# 文本：王五和李四在上海合作。
# PER：[王五, 李四]
# LOC：[上海]
# OFI：[]
#
# 你需要标注的文本如下：
# 壬 子 ， 以 病 谢 事 杜 门 ， 日 以 经 史 自 娱 。 乙 卯 ， 忠 济 使 人 谓 玉 汝 曰 ： 「 君 閒 久 矣 ， 可 暂 起 ， 为 吾 分 忧 。 」 玉 汝 坚 辞 ， 以 参 议 印 强 委 之 ， 不 得 已 起 视 事 ， 仅 五 六 日 ， 裁 画 署 置 ， 焕 然 一 新 。 八 月 既 望 ， 有 星 陨 庭 中 ， 已 而 玉 汝 卒 。
# PER：[]
# LOC：[]
# OFI：[忠济使, 参议印]
#
# 文本：壬 子 ， 以 病 谢 事 杜 门 ， 日 以 经 史 自 娱 。 乙 卯 ， 忠 济 使 人 谓 玉 汝 曰 ： 「 君 閒 久 矣 ， 可 暂 起 ， 为 吾 分 忧 。 」 玉 汝 坚 辞 ， 以 参 议 印 强 委 之 ， 不 得 已 起 视 事 ， 仅 五 六 日 ， 裁 画 署 置 ， 焕 然 一 新 。 八 月 既 望 ， 有 星 陨 庭 中 ， 已
# {'PER': ['人名2', '李四'], 'LOC': ['地名2'], 'OFI': ['机构名2', '忠济使', '参议印']}
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-OFI', 'I-OFI', 'E-OFI', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# F1-macro: 0.2864
